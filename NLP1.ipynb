# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/santosh/anaconda3/lib/python3.7/site-packages (3.4.5)
# Requirement already satisfied: six in /home/santosh/anaconda3/lib/python3.7/site-packages (from nltk) (1.14.0)

# %%
#tokenisation
from nltk.tokenize import word_tokenize, sent_tokenize
para = '''In the early morning hours of May 1, 1898, Commodore George Dewey led a U.S. naval squadron into Manila Bay in the Philippines. He destroyed the anchored Spanish fleet in two hours before pausing the Battle of Manila Bay to order his crew a second breakfast. In total, fewer than 10 American seamen were lost, while Spanish losses were estimated at over 370. Manila itself was occupied by U.S. troops by August.The elusive Spanish Caribbean fleet under Adm. Pascual Cervera was located in Santiago harbor in Cuba by U.S. reconnaissance. An army of regular troops and volunteers under Gen. William Shafter (including then-secretary of the Navy Theodore Roosevelt and his 1st Volunteer Cavalry, the “Rough Riders”) landed on the coast east of Santiago and slowly advanced on the city in an effort to force Cervera’s fleet out of the harbor.Cervera led his squadron out of Santiago on July 3 and tried to escape westward along the coast. In the ensuing battle all of his ships came under heavy fire from U.S. guns and were beached in a burning or sinking condition.Santiago surrendered to Shafter on July 17, thus effectively ending the brief but momentous war.'''

# %%
sentences = sent_tokenize(para)

word = word_tokenize(para)

# %%
sentences
# Out:
# ['In the early morning hours of May 1, 1898, Commodore George Dewey led a U.S. naval squadron into Manila Bay in the Philippines.',
#  'He destroyed the anchored Spanish fleet in two hours before pausing the Battle of Manila Bay to order his crew a second breakfast.',
#  'In total, fewer than 10 American seamen were lost, while Spanish losses were estimated at over 370.',
#  'Manila itself was occupied by U.S. troops by August.The elusive Spanish Caribbean fleet under Adm. Pascual Cervera was located in Santiago harbor in Cuba by U.S. reconnaissance.',
#  'An army of regular troops and volunteers under Gen. William Shafter (including then-secretary of the Navy Theodore Roosevelt and his 1st Volunteer Cavalry, the “Rough Riders”) landed on the coast east of Santiago and slowly advanced on the city in an effort to force Cervera’s fleet out of the harbor.Cervera led his squadron out of Santiago on July 3 and tried to escape westward along the coast.',
#  'In the ensuing battle all of his ships came under heavy fire from U.S. guns and were beached in a burning or sinking condition.Santiago surrendered to Shafter on July 17, thus effectively ending the brief but momentous war.']

# %%
word
# Out:
# ['In',
#  'the',
#  'early',
#  'morning',
#  'hours',
#  'of',
#  'May',
#  '1',
#  ',',
#  '1898',
#  ',',
#  'Commodore',
#  'George',
#  'Dewey',
#  'led',
#  'a',
#  'U.S.',
#  'naval',
#  'squadron',
#  'into',
#  'Manila',
#  'Bay',
#  'in',
#  'the',
#  'Philippines',
#  '.',
#  'He',
#  'destroyed',
#  'the',
#  'anchored',
#  'Spanish',
#  'fleet',
#  'in',
#  'two',
#  'hours',
#  'before',
#  'pausing',
#  'the',
#  'Battle',
#  'of',
#  'Manila',
#  'Bay',
#  'to',
#  'order',
#  'his',
#  'crew',
#  'a',
#  'second',
#  'breakfast',
#  '.',
#  'In',
#  'total',
#  ',',
#  'fewer',
#  'than',
#  '10',
#  'American',
#  'seamen',
#  'were',
#  'lost',
#  ',',
#  'while',
#  'Spanish',
#  'losses',
#  'were',
#  'estimated',
#  'at',
#  'over',
#  '370',
#  '.',
#  'Manila',
#  'itself',
#  'was',
#  'occupied',
#  'by',
#  'U.S.',
#  'troops',
#  'by',
#  'August.The',
#  'elusive',
#  'Spanish',
#  'Caribbean',
#  'fleet',
#  'under',
#  'Adm.',
#  'Pascual',
#  'Cervera',
#  'was',
#  'located',
#  'in',
#  'Santiago',
#  'harbor',
#  'in',
#  'Cuba',
#  'by',
#  'U.S.',
#  'reconnaissance',
#  '.',
#  'An',
#  'army',
#  'of',
#  'regular',
#  'troops',
#  'and',
#  'volunteers',
#  'under',
#  'Gen.',
#  'William',
#  'Shafter',
#  '(',
#  'including',
#  'then-secretary',
#  'of',
#  'the',
#  'Navy',
#  'Theodore',
#  'Roosevelt',
#  'and',
#  'his',
#  '1st',
#  'Volunteer',
#  'Cavalry',
#  ',',
#  'the',
#  '“',
#  'Rough',
#  'Riders',
#  '”',
#  ')',
#  'landed',
#  'on',
#  'the',
#  'coast',
#  'east',
#  'of',
#  'Santiago',
#  'and',
#  'slowly',
#  'advanced',
#  'on',
#  'the',
#  'city',
#  'in',
#  'an',
#  'effort',
#  'to',
#  'force',
#  'Cervera',
#  '’',
#  's',
#  'fleet',
#  'out',
#  'of',
#  'the',
#  'harbor.Cervera',
#  'led',
#  'his',
#  'squadron',
#  'out',
#  'of',
#  'Santiago',
#  'on',
#  'July',
#  '3',
#  'and',
#  'tried',
#  'to',
#  'escape',
#  'westward',
#  'along',
#  'the',
#  'coast',
#  '.',
#  'In',
#  'the',
#  'ensuing',
#  'battle',
#  'all',
#  'of',
#  'his',
#  'ships',
#  'came',
#  'under',
#  'heavy',
#  'fire',
#  'from',
#  'U.S.',
#  'guns',
#  'and',
#  'were',
#  'beached',
#  'in',
#  'a',
#  'burning',
#  'or',
#  'sinking',
#  'condition.Santiago',
#  'surrendered',
#  'to',
#  'Shafter',
#  'on',
#  'July',
#  '17',
#  ',',
#  'thus',
#  'effectively',
#  'ending',
#  'the',
#  'brief',
#  'but',
#  'momentous',
#  'war',
#  '.']

# %%
#regular expression
#actually we are going to use regex for extracting numbers and email id
from nltk.tokenize import regexp_tokenize
regexp_tokenize(para, '[a-z]+')
# Out:
# ['n',
#  'the',
#  'early',
#  'morning',
#  'hours',
#  'of',
#  'ay',
#  'ommodore',
#  'eorge',
#  'ewey',
#  'led',
#  'a',
#  'naval',
#  'squadron',
#  'into',
#  'anila',
#  'ay',
#  'in',
#  'the',
#  'hilippines',
#  'e',
#  'destroyed',
#  'the',
#  'anchored',
#  'panish',
#  'fleet',
#  'in',
#  'two',
#  'hours',
#  'before',
#  'pausing',
#  'the',
#  'attle',
#  'of',
#  'anila',
#  'ay',
#  'to',
#  'order',
#  'his',
#  'crew',
#  'a',
#  'second',
#  'breakfast',
#  'n',
#  'total',
#  'fewer',
#  'than',
#  'merican',
#  'seamen',
#  'were',
#  'lost',
#  'while',
#  'panish',
#  'losses',
#  'were',
#  'estimated',
#  'at',
#  'over',
#  'anila',
#  'itself',
#  'was',
#  'occupied',
#  'by',
#  'troops',
#  'by',
#  'ugust',
#  'he',
#  'elusive',
#  'panish',
#  'aribbean',
#  'fleet',
#  'under',
#  'dm',
#  'ascual',
#  'ervera',
#  'was',
#  'located',
#  'in',
#  'antiago',
#  'harbor',
#  'in',
#  'uba',
#  'by',
#  'reconnaissance',
#  'n',
#  'army',
#  'of',
#  'regular',
#  'troops',
#  'and',
#  'volunteers',
#  'under',
#  'en',
#  'illiam',
#  'hafter',
#  'including',
#  'then',
#  'secretary',
#  'of',
#  'the',
#  'avy',
#  'heodore',
#  'oosevelt',
#  'and',
#  'his',
#  'st',
#  'olunteer',
#  'avalry',
#  'the',
#  'ough',
#  'iders',
#  'landed',
#  'on',
#  'the',
#  'coast',
#  'east',
#  'of',
#  'antiago',
#  'and',
#  'slowly',
#  'advanced',
#  'on',
#  'the',
#  'city',
#  'in',
#  'an',
#  'effort',
#  'to',
#  'force',
#  'ervera',
#  's',
#  'fleet',
#  'out',
#  'of',
#  'the',
#  'harbor',
#  'ervera',
#  'led',
#  'his',
#  'squadron',
#  'out',
#  'of',
#  'antiago',
#  'on',
#  'uly',
#  'and',
#  'tried',
#  'to',
#  'escape',
#  'westward',
#  'along',
#  'the',
#  'coast',
#  'n',
#  'the',
#  'ensuing',
#  'battle',
#  'all',
#  'of',
#  'his',
#  'ships',
#  'came',
#  'under',
#  'heavy',
#  'fire',
#  'from',
#  'guns',
#  'and',
#  'were',
#  'beached',
#  'in',
#  'a',
#  'burning',
#  'or',
#  'sinking',
#  'condition',
#  'antiago',
#  'surrendered',
#  'to',
#  'hafter',
#  'on',
#  'uly',
#  'thus',
#  'effectively',
#  'ending',
#  'the',
#  'brief',
#  'but',
#  'momentous',
#  'war']

# %%
regexp_tokenize(para,'[A-Z][a-z]+')
# Out:
# ['In',
#  'May',
#  'Commodore',
#  'George',
#  'Dewey',
#  'Manila',
#  'Bay',
#  'Philippines',
#  'He',
#  'Spanish',
#  'Battle',
#  'Manila',
#  'Bay',
#  'In',
#  'American',
#  'Spanish',
#  'Manila',
#  'August',
#  'The',
#  'Spanish',
#  'Caribbean',
#  'Adm',
#  'Pascual',
#  'Cervera',
#  'Santiago',
#  'Cuba',
#  'An',
#  'Gen',
#  'William',
#  'Shafter',
#  'Navy',
#  'Theodore',
#  'Roosevelt',
#  'Volunteer',
#  'Cavalry',
#  'Rough',
#  'Riders',
#  'Santiago',
#  'Cervera',
#  'Cervera',
#  'Santiago',
#  'July',
#  'In',
#  'Santiago',
#  'Shafter',
#  'July']

# %%
regexp_tokenize(para,'[0-9]+')
# Out:
# ['1', '1898', '10', '370', '1', '3', '17']

# %%
regexp_tokenize(para,'[\a-z]+')
# Out:
# ['In the early morning hours of May 1, 1898, Commodore George Dewey led a U.S. naval squadron into Manila Bay in the Philippines. He destroyed the anchored Spanish fleet in two hours before pausing the Battle of Manila Bay to order his crew a second breakfast. In total, fewer than 10 American seamen were lost, while Spanish losses were estimated at over 370. Manila itself was occupied by U.S. troops by August.The elusive Spanish Caribbean fleet under Adm. Pascual Cervera was located in Santiago harbor in Cuba by U.S. reconnaissance. An army of regular troops and volunteers under Gen. William Shafter (including then-secretary of the Navy Theodore Roosevelt and his 1st Volunteer Cavalry, the ',
#  'Rough Riders',
#  ') landed on the coast east of Santiago and slowly advanced on the city in an effort to force Cervera',
#  's fleet out of the harbor.Cervera led his squadron out of Santiago on July 3 and tried to escape westward along the coast. In the ensuing battle all of his ships came under heavy fire from U.S. guns and were beached in a burning or sinking condition.Santiago surrendered to Shafter on July 17, thus effectively ending the brief but momentous war.']

# %%
regexp_tokenize(para, '[^a-z]+')
# Out:
# ['I',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' M',
#  ' 1, 1898, C',
#  ' G',
#  ' D',
#  ' ',
#  ' ',
#  ' U.S. ',
#  ' ',
#  ' ',
#  ' M',
#  ' B',
#  ' ',
#  ' ',
#  ' P',
#  '. H',
#  ' ',
#  ' ',
#  ' ',
#  ' S',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' B',
#  ' ',
#  ' M',
#  ' B',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '. I',
#  ' ',
#  ', ',
#  ' ',
#  ' 10 A',
#  ' ',
#  ' ',
#  ' ',
#  ', ',
#  ' S',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' 370. M',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' U.S. ',
#  ' ',
#  ' A',
#  '.T',
#  ' ',
#  ' S',
#  ' C',
#  ' ',
#  ' ',
#  ' A',
#  '. P',
#  ' C',
#  ' ',
#  ' ',
#  ' ',
#  ' S',
#  ' ',
#  ' ',
#  ' C',
#  ' ',
#  ' U.S. ',
#  '. A',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' G',
#  '. W',
#  ' S',
#  ' (',
#  ' ',
#  '-',
#  ' ',
#  ' ',
#  ' N',
#  ' T',
#  ' R',
#  ' ',
#  ' ',
#  ' 1',
#  ' V',
#  ' C',
#  ', ',
#  ' “R',
#  ' R',
#  '”) ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' S',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' C',
#  '’',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.C',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' S',
#  ' ',
#  ' J',
#  ' 3 ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '. I',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' U.S. ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.S',
#  ' ',
#  ' ',
#  ' S',
#  ' ',
#  ' J',
#  ' 17, ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.']

# %%
regexp_tokenize(para,'[^0-9]+')
# Out:
# ['In the early morning hours of May ',
#  ', ',
#  ', Commodore George Dewey led a U.S. naval squadron into Manila Bay in the Philippines. He destroyed the anchored Spanish fleet in two hours before pausing the Battle of Manila Bay to order his crew a second breakfast. In total, fewer than ',
#  ' American seamen were lost, while Spanish losses were estimated at over ',
#  '. Manila itself was occupied by U.S. troops by August.The elusive Spanish Caribbean fleet under Adm. Pascual Cervera was located in Santiago harbor in Cuba by U.S. reconnaissance. An army of regular troops and volunteers under Gen. William Shafter (including then-secretary of the Navy Theodore Roosevelt and his ',
#  'st Volunteer Cavalry, the “Rough Riders”) landed on the coast east of Santiago and slowly advanced on the city in an effort to force Cervera’s fleet out of the harbor.Cervera led his squadron out of Santiago on July ',
#  ' and tried to escape westward along the coast. In the ensuing battle all of his ships came under heavy fire from U.S. guns and were beached in a burning or sinking condition.Santiago surrendered to Shafter on July ',
#  ', thus effectively ending the brief but momentous war.']

# %% [raw]
# With the use of regex we can extract the text

# %%
#stopwords are the words that are not useful so we shoud remove that so that there will be no noise for the 
from nltk.corpus import stopwords

# %%
stop_w = stopwords.words('english')
stop_w
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import nltk
import string
data = '''In the early morning hours of May 1, 1898, Commodore George Dewey led a U.S. naval squadron into Manila Bay in the Philippines. He destroyed the anchored Spanish fleet in two hours before pausing the Battle of Manila Bay to order his crew a second breakfast. In total, fewer than 10 American seamen were lost, while Spanish losses were estimated at over 370. Manila itself was occupied by U.S. troops by August.The elusive Spanish Caribbean fleet under Adm. Pascual Cervera was located in Santiago harbor in Cuba by U.S. reconnaissance. An army of regular troops and volunteers under Gen. William Shafter (including then-secretary of the Navy Theodore Roosevelt and his 1st Volunteer Cavalry, the “Rough Riders”) landed on the coast east of Santiago and slowly advanced on the city in an effort to force Cervera’s fleet out of the harbor.Cervera led his squadron out of Santiago on July 3 and tried to escape westward along the coast. In the ensuing battle all of his ships came under heavy fire from U.S. guns and were beached in a burning or sinking condition.Santiago surrendered to Shafter on July 17, thus effectively ending the brief but momentous war.'''

cleaned_text = []

for word in nltk.word_tokenize(data):
    if word not in string.punctuation:
        if word not in stop_w:
            cleaned_text.append(word)
print(len(data))
print(len(cleaned_text))
print(cleaned_text)
# Out:
# 1158
# 127
# ['In', 'early', 'morning', 'hours', 'May', '1', '1898', 'Commodore', 'George', 'Dewey', 'led', 'U.S.', 'naval', 'squadron', 'Manila', 'Bay', 'Philippines', 'He', 'destroyed', 'anchored', 'Spanish', 'fleet', 'two', 'hours', 'pausing', 'Battle', 'Manila', 'Bay', 'order', 'crew', 'second', 'breakfast', 'In', 'total', 'fewer', '10', 'American', 'seamen', 'lost', 'Spanish', 'losses', 'estimated', '370', 'Manila', 'occupied', 'U.S.', 'troops', 'August.The', 'elusive', 'Spanish', 'Caribbean', 'fleet', 'Adm.', 'Pascual', 'Cervera', 'located', 'Santiago', 'harbor', 'Cuba', 'U.S.', 'reconnaissance', 'An', 'army', 'regular', 'troops', 'volunteers', 'Gen.', 'William', 'Shafter', 'including', 'then-secretary', 'Navy', 'Theodore', 'Roosevelt', '1st', 'Volunteer', 'Cavalry', '“', 'Rough', 'Riders', '”', 'landed', 'coast', 'east', 'Santiago', 'slowly', 'advanced', 'city', 'effort', 'force', 'Cervera', '’', 'fleet', 'harbor.Cervera', 'led', 'squadron', 'Santiago', 'July', '3', 'tried', 'escape', 'westward', 'along', 'coast', 'In', 'ensuing', 'battle', 'ships', 'came', 'heavy', 'fire', 'U.S.', 'guns', 'beached', 'burning', 'sinking', 'condition.Santiago', 'surrendered', 'Shafter', 'July', '17', 'thus', 'effectively', 'ending', 'brief', 'momentous', 'war']

# %%
from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()
lemma_words = lemma.lemmatize(data)
lemma_words
# Out:
# 'In the early morning hours of May 1, 1898, Commodore George Dewey led a U.S. naval squadron into Manila Bay in the Philippines. He destroyed the anchored Spanish fleet in two hours before pausing the Battle of Manila Bay to order his crew a second breakfast. In total, fewer than 10 American seamen were lost, while Spanish losses were estimated at over 370. Manila itself was occupied by U.S. troops by August.The elusive Spanish Caribbean fleet under Adm. Pascual Cervera was located in Santiago harbor in Cuba by U.S. reconnaissance. An army of regular troops and volunteers under Gen. William Shafter (including then-secretary of the Navy Theodore Roosevelt and his 1st Volunteer Cavalry, the “Rough Riders”) landed on the coast east of Santiago and slowly advanced on the city in an effort to force Cervera’s fleet out of the harbor.Cervera led his squadron out of Santiago on July 3 and tried to escape westward along the coast. In the ensuing battle all of his ships came under heavy fire from U.S. guns and were beached in a burning or sinking condition.Santiago surrendered to Shafter on July 17, thus effectively ending the brief but momentous war.'
