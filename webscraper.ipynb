# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
dfs = pd.read_html("https://en.wikipedia.org/wiki/2020_in_anime")

# %%
dfs[1]
# Out:
#               Release date                                              Title  \
# 0               January 10                        The Island of Giant Insects
# 1               January 17               Made in Abyss: Dawn of the Deep Soul
# 2               January 18                        High School Fleet the Movie
# 3               February 1                      Goblin Slayer: Goblin's Crown
# 4              February 15    Saezuru Tori wa Habatakanai – The Clouds Gather
# 5              February 21           Digimon Adventure: Last Evolution Kizuna
# 6              February 21                   Sekai-ichi Hatsukoi: Propose-hen
# 7              February 29                                    Shirobako Movie
# 8                 March 27                     Psycho-Pass 3: First Inspector
# 9                 August 7                    Doraemon: Nobita's New Dinosaur
# 10                August 7                  Revue Starlight Rondo Rondo Rondo
# ...

# %%
dfs[2]
# Out:
#     First run start and end dates  \
# 0            January 3 – March 27
# 1            January 3 – March 20
# 2            January 4 – March 28
# 3            January 5 – March 22
# 4            January 5 – March 22
# ..                            ...
# 134                  October 13 –
# 135                  October 13 –
# 136                  October 14 –
# 137                  October 30 –
# 138                  December 7 –
#
#                                                  Title  Episodes  \
# 0                                     Asteroid in Love      12.0
# 1                                        Darwin's Game      11.0
# 2    Magia Record: Puella Magi Madoka Magica Side S...      13.0
# 3                                          Id: Invaded      13.0
# 4                        Keep Your Hands Off Eizouken!      12.0
# ..                                                 ...       ...
# 134                          Magatsu Wahrheit -Zuerst-       NaN
# ...

# %%
dfs[2].to_csv("animelist3.csv", index = 'false', encoding='utf-8')

# %%
dfs[3]
# Out:
#    First run start and end dates  \
# 0          January 15 – August 6
# 1                     February 6
# 2                       March 19
# 3                       March 20
# 4                       March 23
# 5                       March 26
# 6            April 9 – August 27
# 7                     April 10 –
# 8             April 10 – June 26
# 9                       April 23
# 10                        June 4
# 11                       June 18
# 12                        July 9
# 13                     August 16
# 14                     August 27
# 15                  September 17
# 16                    October 11
# 17                  October 11 –
# 18                    December 1
#
#                                                 Title  Episodes  \
# 0                             Pokémon: Twilight Wings       7.0
# 1                          Cagaster of an Insect Cage      12.0
# 2                           Altered Carbon: Resleeved       1.0
# ...

# %%
dfs[4]
# Out:
#    First run start and end dates  \
# 0                     January 22
# 1                     January 22
# 2                     January 29
# 3                     January 29
# 4                    February 14
# 5                    February 27
# 6                    February 28
# 7                    February 27
# 8                       March 25
# 9                        April 3
# 10       April 8 – June 30, 2021
# 11                     August 26
# 12                   September 2
# 13      October 25 – November 29
#
#                                                 Title  Episodes  \
# 0                               Haikyu!! Land vs. Sky         2
# 1                                           Tsugumomo         1
# 2   Is It Wrong to Try to Pick Up Girls in a Dungeon?         1
# 3                   Strike the Blood: Kieta Seisō-hen         1
# 4       ACCA: 13-Territory Inspection Dept. - Regards         1
# 5                                     The Ones Within         1
# ...

# %%
dfs[5]
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteYears in anime  \
# 0                                   History of anime
# ...

# %%
dfs
# Out:
# [    0                                                  1
#  0 NaN  This article possibly contains original resear...,
#                                            English name  \
#  0                                      Abashiri Family
#  1                                         Absolute Duo
#  2                              A Certain Magical Index
#  3                           A Certain Magical Index II
#  4    A Certain Magical Index: The Movie - The Mirac...
#  ..                                                 ...
#  123                                Sword Art Online II
#  124                                      Trinity Blood
#  125                            Neon Genesis Evangelion
#  126                                     Virtua Fighter
#  127                                     mob psycho 100
#
#                                           Japanese name       Type  Year  \
#  0                                Abashiri Ikka (あばしり一家        OVA  1991
# ...

# %%
dfs[1]
# Out:
#                                           English name  \
# 0                                      Abashiri Family
# 1                                         Absolute Duo
# 2                              A Certain Magical Index
# 3                           A Certain Magical Index II
# 4    A Certain Magical Index: The Movie - The Mirac...
# ..                                                 ...
# 123                                Sword Art Online II
# 124                                      Trinity Blood
# 125                            Neon Genesis Evangelion
# 126                                     Virtua Fighter
# 127                                     mob psycho 100
#
#                                          Japanese name       Type  Year  \
# 0                                Abashiri Ikka (あばしり一家        OVA  1991
# 1                             アブソリュート・デュオ Absolute Duo  TV series  2015
# 2                    とある魔術の Toaru Majutsu no Indekkusu  TV series  2008
# ...

# %%
dfs[2]
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteLists of anime and manga  \
# ...

# %%
dfs[1].to_csv('animelist.csv', encoding='utf-8')

# %%
dfs[2].to_csv("animelist4.csv", index = 'false', encoding='utf-8')

# %%
dfs[3].to_csv('animelist2.csv', index = 'false', encoding='utf-8')

# %%
dfs[4].to_csv('animelist3.csv', index = 'false', encoding ='utf-8')

# %% [markdown]
# # # # pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("animelist.csv")

# %%
engname = soup.find('th').text[:-1]
engname
# Out:
# 'English name'

# %%
wikitable sortable plainrowheaders jquery-tablesorter

# %%
pip install html-parser
