# %%
import os

# %%
os.getcwd()
# Out:
# '/home/santosh/code_git'

# %%
os.listdir()
# Out:
# ['dogs.csv',
#  'titanic_train.csv',
#  'SVCmodel',
#  'census_data.html',
#  'UFO.xlsx',
#  'titanic.csv',
#  'animelist2.csv',
#  'concretedecmodel',
#  'LinearDiscriminantanalysis',
#  'DSData',
#  'Flight-Price-Prediction',
#  'bigdatamart_Train.csv',
#  'strongmodel',
#  'animelist3.csv',
#  'classification_banknot.ipynb',
#  'test_datamart.csv',
#  'Avocado_price_prediction.ipynb',
#  'DecisionTreeRegressor.obj',
#  'fish.csv',
#  'forest.csv',
#  'pattern.py',
#  'Movie-Recommender-in-python',
#  'IRIS_using_Pipelines.ipynb',
#  'concrete_data.csv',
#  'random_model.obj',
#  'Untitled.ipynb',
#  'happiness_submission.csv',
#  'Boston_house_Data_Linear regresssion.ipynb',
#  'web_scraping',
#  'matplotlib and seaborn.ipynb',
#  'sample.json',
#  'titanic_submission_v02.csv',
#  'model_joblib',
#  'dataset1',
#  'train_datamart.csv',
#  'Advertisement_prediction.csv',
#  'new1.ipynb',
#  'happiness_score_dataset.csv',
#  'Randommodel',
#  'best.obj',
#  'crossvalidation.ipynb',
# ...

# %%
os.chdir('/home/santosh/code')

# %%
os.getcwd()
# Out:
# '/home/santosh/code'

# %%
os.chdir('/home/santosh/code_git')

# %%
os.environ.get('HOME')
# Out:
# '/home/santosh'

# %%
filepath = os.path.join(os.environ.get('HOME'), 'dogs.csv')

# %%
filepath
# Out:
# '/home/santosh/dogs.csv'

# %%
os.listdir()
# Out:
# ['dogs.csv',
#  'titanic_train.csv',
#  'SVCmodel',
#  'census_data.html',
#  'UFO.xlsx',
#  'titanic.csv',
#  'animelist2.csv',
#  'concretedecmodel',
#  'LinearDiscriminantanalysis',
#  'DSData',
#  'Flight-Price-Prediction',
#  'bigdatamart_Train.csv',
#  'strongmodel',
#  'animelist3.csv',
#  'classification_banknot.ipynb',
#  'test_datamart.csv',
#  'Avocado_price_prediction.ipynb',
#  'DecisionTreeRegressor.obj',
#  'fish.csv',
#  'forest.csv',
#  'pattern.py',
#  'Movie-Recommender-in-python',
#  'IRIS_using_Pipelines.ipynb',
#  'concrete_data.csv',
#  'random_model.obj',
#  'Untitled.ipynb',
#  'happiness_submission.csv',
#  'Boston_house_Data_Linear regresssion.ipynb',
#  'web_scraping',
#  'matplotlib and seaborn.ipynb',
#  'sample.json',
#  'titanic_submission_v02.csv',
#  'model_joblib',
#  'dataset1',
#  'train_datamart.csv',
#  'Advertisement_prediction.csv',
#  'new1.ipynb',
#  'happiness_score_dataset.csv',
#  'Randommodel',
#  'best.obj',
#  'crossvalidation.ipynb',
# ...

# %%
os.envir`
